# %%
# Import lớp Image
from PIL import Image
from imgtools import *

# %%
my_path = 'D:/hoctap/hk7/tgmt/image/i02.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x384>

# %%
print(img.size)
# Out:
# (612, 384)

# %%
#thay đổi kích cở : 
new_size = (100,100)
new_image = img.resize(new_size)
display(new_image)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
img.save('new1.png')

# %%
# Out:
#   Cell In[2], line 1
#     |#thay đổi kích cỡ cách 2 :
#     ^
# SyntaxError: invalid syntax
